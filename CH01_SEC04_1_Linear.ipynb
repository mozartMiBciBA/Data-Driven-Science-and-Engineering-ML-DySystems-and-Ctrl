# %% [markdown]
# <a href="https://colab.research.google.com/github/mozartMiBciBA/Data-Driven-Science-and-Engineering-ML-DySystems-and-Ctrl/blob/main/CH01_SEC04_1_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression 1 [Python]
#
# Fuente1: https://www.youtube.com/watch?v=q6ksri0LeDE&list=PLMrJAkhIeNNSVjnsviglFoY2nXildDCcv&index=19
#
#
# Fuente2: http://databookuw.com/
#
# Fuente3: http://databookuw.com/databook.pdf
#
# Fuente 4: eigensteve.com

# %% [markdown]
# Modelo de regresión lineal
#
# $$ Ax=b$$

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 18})

x = 3 # True slope
a = np.arange(-2,2,0.25)
a = a.reshape(-1, 1)
#print("a:", a, "a.reshape:", a.shape)
b = x*a + np.random.randn(*a.shape) # Add noise
plt.plot(a, x*a, Color='k', LineWidth=2, label='True line') # True relationship ax = b
plt.plot(a, b, 'x', Color='r', MarkerSize = 8, label='Noisy data') # Noisy measurements

U, S, VT = np.linalg.svd(a,full_matrices=False)
xtilde = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b # Least-square fit
#print()
#print("xtilde")
#print(xtilde)

#####
# Other Two methods of computing regression

# xtilde1 = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b
# xtilde2 = np.linalg.pinv(a) @ b
#####

plt.plot(a,xtilde * a,'--',Color='b',LineWidth=4, label='Regression line')

plt.xlabel('a')
plt.ylabel('b')

plt.grid(linestyle='--')
plt.legend()
plt.show()

# %%
# Two methods of computing regression

xtilde1 = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b
xtilde2 = np.linalg.pinv(a) @ b
